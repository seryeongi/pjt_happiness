# %%
import plotly
import plotly.express as px
import pandas as pd

df = pd.read_csv('C:\BigdataProjects\BigdataService_team1\project01\data\data01.csv')
print(df)
# Out:
#       year      country         region  rank  score  social_support    health  \
# 0     2015  Switzerland         Europe     1  7.587         1.34951   0.94143
# 1     2015      Iceland         Europe     2  7.561         1.40223   0.94784
# 2     2015      Denmark         Europe     3  7.527         1.36058   0.87464
# 3     2015       Norway         Europe     4  7.522         1.33095   0.88521
# 4     2015       Canada  North America     5  7.427         1.32261   0.90563
# ...    ...          ...            ...   ...    ...             ...       ...
# 1079  2021      Lesotho         Africa   145  3.512         0.78700  48.70000
# 1080  2021     Botswana         Africa   146  3.467         0.78400  59.26900
# 1081  2021       Rwanda         Africa   147  3.415         0.55200  61.40000
# 1082  2021     Zimbabwe         Africa   148  3.145         0.75000  56.20100
# 1083  2021  Afghanistan           Asia   149  2.523         0.46300  52.49300
#
# ...

# %%
fig = px.scatter(df, x="gdp_std", y="score", animation_frame="year", animation_group="country", color="region", hover_name="country", facet_col="region",
           log_x=False, size_max=45, range_x=[-3,3], range_y=[0,10])
fig.show()
# Out:
# <div>                            <div id="d4fcbf9a-7c67-4dda-b11a-ac52b6b6ed60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4fcbf9a-7c67-4dda-b11a-ac52b6b6ed60")) {                    Plotly.newPlot(                        "d4fcbf9a-7c67-4dda-b11a-ac52b6b6ed60",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>region=Europe<br>year=2015<br>gdp_std=%{x}<br>score=%{y}<extra></extra>","hovertext":["Switzerland","Iceland","Denmark","Norway","Finland","Netherlands","Sweden","Austria","Luxembourg","Ireland","Belgium","United Kingdom","Germany","France","Czech Republic","Spain","Malta","Uzbekistan","Slovakia","Italy","Moldova","Kazakhstan","Slovenia","Lithuania","Belarus","Poland","Croatia","Russia","North Cyprus","Cyprus","Kosovo"
# ...

# %%
fig = px.scatter(df, x="health_std", y="score", animation_frame="year", animation_group="country", color="region", hover_name="country", facet_col="region",
           log_x=False, size_max=45, range_x=[-3,3], range_y=[0,10])
fig.show()
# Out:
# <div>                            <div id="6977566f-2fca-46d3-a5e6-da84efab946f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6977566f-2fca-46d3-a5e6-da84efab946f")) {                    Plotly.newPlot(                        "6977566f-2fca-46d3-a5e6-da84efab946f",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>region=Europe<br>year=2015<br>health_std=%{x}<br>score=%{y}<extra></extra>","hovertext":["Switzerland","Iceland","Denmark","Norway","Finland","Netherlands","Sweden","Austria","Luxembourg","Ireland","Belgium","United Kingdom","Germany","France","Czech Republic","Spain","Malta","Uzbekistan","Slovakia","Italy","Moldova","Kazakhstan","Slovenia","Lithuania","Belarus","Poland","Croatia","Russia","North Cyprus","Cyprus","Koso
# ...

# %%
fig = px.scatter(df, x="dystopia_std", y="score", animation_frame="year", animation_group="country", color="region", hover_name="country", facet_col="region"
           ,log_x=False, size_max=45, range_x=[-3,3], range_y=[0,10])
fig.show()
# Out:
# <div>                            <div id="9ecdd2c8-f7f1-4ae0-94dc-38cc34689eb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ecdd2c8-f7f1-4ae0-94dc-38cc34689eb1")) {                    Plotly.newPlot(                        "9ecdd2c8-f7f1-4ae0-94dc-38cc34689eb1",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>region=Europe<br>year=2015<br>dystopia_std=%{x}<br>score=%{y}<extra></extra>","hovertext":["Switzerland","Iceland","Denmark","Norway","Finland","Netherlands","Sweden","Austria","Luxembourg","Ireland","Belgium","United Kingdom","Germany","France","Czech Republic","Spain","Malta","Uzbekistan","Slovakia","Italy","Moldova","Kazakhstan","Slovenia","Lithuania","Belarus","Poland","Croatia","Russia","North Cyprus","Cyprus","Ko
# ...
